# %% [markdown]
# # Superstore Sales Analysis
# Portfolio analysis using Python, Pandas, Matplotlib/Seaborn, and SQL.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/superstore_cleaned.csv', parse_dates=['order_date','ship_date'])
df.head()

# %%
summary = df.groupby('category')[['sales','profit']].sum().sort_values('profit', ascending=False)
summary
